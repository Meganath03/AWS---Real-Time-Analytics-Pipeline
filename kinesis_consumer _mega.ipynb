# %%
# !pip install boto3

# %%
import os
os.environ['AWS_ACCESS_KEY_ID'] = 'AKIAYWBJYP5P5GZWEQR7'
os.environ['AWS_SECRET_ACCESS_KEY'] = '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'
os.environ['AWS_DEFAULT_REGION'] = 'eu-north-1'

# %%
import boto3
import json
kinesis_client = boto3.client(
    'kinesis',
    aws_access_key_id='AKIAYWBJYP5P5GZWEQR7',
    aws_secret_access_key='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',
    region_name='eu-north-1'
)
STREAM_NAME = "my-stream"
def consume_data_from_kinesis():
    """Consume data from Kinesis stream."""
    shard_iterator = None
    response = kinesis_client.describe_stream(StreamName=STREAM_NAME)
    shard_id = response['StreamDescription']['Shards'][0]['ShardId']
    shard_iterator = kinesis_client.get_shard_iterator(
        StreamName=STREAM_NAME,
        ShardId=shard_id,
        ShardIteratorType='TRIM_HORIZON'
    )['ShardIterator']
    while True:
        record_response = kinesis_client.get_records(ShardIterator=shard_iterator, Limit=10)

        for record in record_response['Records']:
            data = json.loads(record['Data'].decode('utf-8'))
            print(f"Received data: {data}")
        shard_iterator = record_response['NextShardIterator']
if __name__ == "__main__":
    consume_data_from_kinesis()
# Out:
# Received data: {'sensor_id': 'sensor-87', 'temperature': -3, 'humidity': 21, 'timestamp': 1733637088}
# Received data: {'sensor_id': 'sensor-46', 'temperature': -8, 'humidity': 19, 'timestamp': 1733637089}
# Received data: {'sensor_id': 'sensor-25', 'temperature': 1, 'humidity': 70, 'timestamp': 1733637091}
# Received data: {'sensor_id': 'sensor-53', 'temperature': 27, 'humidity': 73, 'timestamp': 1733637093}
# Received data: {'sensor_id': 'sensor-46', 'temperature': -8, 'humidity': 10, 'timestamp': 1733637095}
# Received data: {'sensor_id': 'sensor-78', 'temperature': -3, 'humidity': 71, 'timestamp': 1733637103}
# Received data: {'sensor_id': 'sensor-53', 'temperature': 28, 'humidity': 67, 'timestamp': 1733637104}
# Received data: {'sensor_id': 'sensor-12', 'temperature': 24, 'humidity': 68, 'timestamp': 1733637107}
# Received data: {'sensor_id': 'sensor-53', 'temperature': -20, 'humidity': 19, 'timestamp': 1733637110}
# ...
